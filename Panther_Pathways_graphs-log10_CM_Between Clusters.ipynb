# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df3 = pd.read_csv('./CM3_Panther_Pathways.csv')
df3.head(10)
#this is between clusters as there were so few wt in this population
# Out:
#                                     Panther Pathways  Fold Enrichment  \
# 0                Cadherin signaling pathway (P00012)             5.68
# 1     Cytoskeletal regulation by Rho GTPase (P00016)             7.37
# 2      Alzheimer disease-presenilin pathway (P00004)             6.36
# 3  Nicotinic acetylcholine receptor signaling pat...             7.30
# 4                        CCKR signaling map (P06959)             6.46
#
#     p-value  log10pvalue Reg
# 0  0.049400     1.306273  up
# 1  0.010700     1.970616  up
# 2  0.008750     2.057992  up
# 3  0.003430     2.464706  up
# 4  0.000308     3.511449  up

# %%
x3 = np.arange(len(df3['Panther Pathways'] ))
plt.rcParams["figure.figsize"] = [10, 8]
df3["log10pvalue"].plot(kind='barh', legend=False, 
                color=(df3['Fold Enrichment'] > 0).map({True: 'yellowgreen',
                                                    False: 'indianred'}))
plt.title("Differentially regulated Panther Pathways in CM3")
plt.xlabel('-log10(p value)')
plt.ylabel("Panther Pathways")
plt.yticks(x3, df3["Panther Pathways"])
plt.savefig('Differentially regulated Panther Pathways in CM3.png',dpi=300, bbox_inches='tight')

# %%
df1 = pd.read_csv('./CM1_Panther_Pathways.csv')
df1.head(3)
# Out:
#                                     Panther Pathways  Fold Enrichment  \
# 0               Integrin signalling pathway (P00034)            -5.25
# 1     Cytoskeletal regulation by Rho GTPase (P00016)           -10.18
# 2  Nicotinic acetylcholine receptor signaling pat...           -11.03
#
#     p-value  log10pvalue   Reg
# 0  0.011800     1.928118  down
# 1  0.000323     3.490797  down
# 2  0.000008     5.086716  down

# %%
x1 = np.arange(len(df1['Panther Pathways'] ))
plt.rcParams["figure.figsize"] = [10, 15]
df1["log10pvalue"].plot(kind='barh', legend=False, 
                color=(df1['Fold Enrichment'] > 0).map({True: 'yellowgreen',
                                                    False: 'indianred'}))
plt.title("Differentially regulated Panther Pathways in CM1")
plt.xlabel('-log10(p value)')
plt.ylabel("Panther Pathways")
plt.yticks(x1, df1["Panther Pathways"])
plt.savefig('Differentially regulated Panther Pathways in CM1.png',dpi=300, bbox_inches='tight')

# %%
df2 = pd.read_csv('./CM2_Panther_Pathways.csv')
df2.head(10)
# Out:
#                                     Panther Pathways  Fold Enrichment  \
# 0  Nicotinic acetylcholine receptor signaling pat...             9.01
#
#    p-value  log10pvalue Reg
# 0  0.00288     2.540608  up

# %%
x2 = np.arange(len(df2['Panther Pathways'] ))
plt.rcParams["figure.figsize"] = [10, 15]
df2["log10pvalue"].plot(kind='barh', legend=False, 
                color=(df2['Fold Enrichment'] > 0).map({True: 'yellowgreen',
                                                    False: 'indianred'}))
plt.title("Differentially regulated Panther Pathways in CM2")
plt.xlabel('-log10(p value)')
plt.ylabel("Panther Pathways")
plt.yticks(x2, df2["Panther Pathways"])
plt.savefig('Differentially regulated Panther Pathways in CM2.png',dpi=300, bbox_inches='tight')

# %%
df4 = pd.read_csv('./CM4_Panther_Pathways.csv')
df4.head(10)
# Out:
#                                     Panther Pathways  Fold Enrichment  \
# 0     Cytoskeletal regulation by Rho GTPase (P00016)             5.22
# 1                TGF-beta signaling pathway (P00052)             4.81
# 2                        CCKR signaling map (P06959)             4.53
# 3               Integrin signalling pathway (P00034)             4.26
# 4  Gonadotropin-releasing hormone receptor pathwa...             4.16
#
#     p-value  log10pvalue Reg
# 0  0.015300     1.815309  up
# 1  0.012100     1.917215  up
# 2  0.000888     3.051587  up
# 3  0.000410     3.387216  up
# 4  0.000066     4.180456  up

# %%
x4 = np.arange(len(df4['Panther Pathways'] ))
plt.rcParams["figure.figsize"] = [10, 15]
df4["log10pvalue"].plot(kind='barh', legend=False, 
                color=(df4['Fold Enrichment'] > 0).map({True: 'yellowgreen',
                                                    False: 'indianred'}))
plt.title("Differentially regulated Panther Pathways in CM4")
plt.xlabel('-log10(p value)')
plt.ylabel("Panther Pathways")
plt.yticks(x4, df4["Panther Pathways"])
plt.savefig('Differentially regulated Panther Pathways in CM4.png',dpi=300, bbox_inches='tight')

# %% [markdown]
# df5 = pd.read_csv('./CM5_GO_Molecular_Function.csv')
# df5.head(10)

# %% [markdown]
# x5 = np.arange(len(df5['GO Biological processes'] ))
# plt.rcParams["figure.figsize"] = [10, 15]
# df5["log10pvalue"].plot(kind='barh', legend=False,
#                 color=(df5['Fold Enrichment'] > 0).map({True: 'yellowgreen',
#                                                     False: 'indianred'}))
# plt.title("Differentially regulated GO Molecular Function in CM5")
# plt.xlabel('-log10(p value)')
# plt.ylabel("GO Molecular Function")
# plt.yticks(x5, df5["GO Biological processes"])
# plt.savefig('Differentially regulated GO Molecular Function in CM5.png',dpi=300, bbox_inches='tight')

# %%
df6 = pd.read_csv('./CM6_Panther_Pathways.csv')
df6.head(10)
# Out:
#                    Panther Pathway  Fold Enrichment  p-value  log10pvalue Reg
# 0  PDGF signaling pathway (P00047)            14.28   0.0295     1.530178  up

# %%
x6 = np.arange(len(df6['Panther Pathway'] ))
plt.rcParams["figure.figsize"] = [10, 15]
df6["log10pvalue"].plot(kind='barh', legend=False, 
                color=(df6['Fold Enrichment'] > 0).map({True: 'yellowgreen',
                                                    False: 'indianred'}))
plt.title("Differentially regulated Panther Pathways in CM6")
plt.xlabel('-log10(p value)')
plt.ylabel("Panther Pathways")
plt.yticks(x6, df6["Panther Pathway"])
plt.savefig('Differentially regulated Panther Pathways in CM6.png',dpi=300, bbox_inches='tight')

# %%
df7 = pd.read_csv('./CM7_Panther_Pathways.csv')
df7.head(10)
# Out:
#                              GO Biological processes  Fold Enrichment  \
# 0                        Huntington disease (P00029)             9.85
# 1      Alzheimer disease-presenilin pathway (P00004)            13.87
# 2                Cadherin signaling pathway (P00012)            14.16
# 3     Cytoskeletal regulation by Rho GTPase (P00016)            18.37
# 4  Nicotinic acetylcholine receptor signaling pat...            19.12
#
#     p-value  log10pvalue Reg
# 0  0.026800     1.571865  up
# 1  0.005570     2.254145  up
# 2  0.005060     2.295849  up
# 3  0.001510     2.821023  up
# 4  0.000147     3.832683  up

# %%
x7 = np.arange(len(df7['GO Biological processes'] ))
plt.rcParams["figure.figsize"] = [10, 15]
df7["log10pvalue"].plot(kind='barh', legend=False, 
                color=(df7['Fold Enrichment'] > 0).map({True: 'yellowgreen',
                                                    False: 'indianred'}))
plt.title("Differentially regulated Panther Pathways in CM7")
plt.xlabel('-log10(p value)')
plt.ylabel("Panther Pathways")
plt.yticks(x7, df7["GO Biological processes"])
plt.savefig('Differentially regulated Panther Pathways in CM7.png',dpi=300, bbox_inches='tight')

# %% [markdown]
# df8 = pd.read_csv('./CM8_GO_Molecular_Function.csv')
# df8.head(10)

# %% [markdown]
# x8 = np.arange(len(df8['GO Biological processes'] ))
# plt.rcParams["figure.figsize"] = [10, 15]
# df8["log10pvalue"].plot(kind='barh', legend=False,
#                 color=(df8['Fold Enrichment'] > 0).map({True: 'yellowgreen',
#                                                     False: 'indianred'}))
# plt.title("Differentially regulated GO Molecular Function in CM8")
# plt.xlabel('-log10(p value)')
# plt.ylabel("GO Molecular Function")
# plt.yticks(x8, df8["GO Biological processes"])
# plt.savefig('Differentially regulated GO Molecular Function in CM8.png',dpi=300, bbox_inches='tight')

# %%
df9 = pd.read_csv('./CM9_Panther_Pathways.csv')
df9.head(10)
# Out:
#                Panther Pathway  Fold Enrichment  p-value  log10pvalue   Reg
# 0  CCKR signaling map (P06959)            -9.64     0.03     1.522879  down

# %%
x9 = np.arange(len(df9['Panther Pathway'] ))
plt.rcParams["figure.figsize"] = [10, 15]
df9["log10pvalue"].plot(kind='barh', legend=False, 
                color=(df9['Fold Enrichment'] > 0).map({True: 'yellowgreen',
                                                    False: 'indianred'}))
plt.title("Differentially regulated Panther Pathways in CM9")
plt.xlabel('-log10(p value)')
plt.ylabel("Panther Pathways")
plt.yticks(x9, df9["Panther Pathway"])
plt.savefig('Differentially regulated Panther Pathways in CM9.png',dpi=300, bbox_inches='tight')

# %%
df10 = pd.read_csv('./CM10_Panther_Pathways.csv')
df10.head(10)
# Out:
#                                      Panther Pathway  Fold Enrichment  \
# 0  Inflammation mediated by chemokine and cytokin...            -6.27
# 1  Nicotinic acetylcholine receptor signaling pat...           -11.54
# 2     Cytoskeletal regulation by Rho GTPase (P00016)           -13.31
#
#    p-value  log10pvalue   Reg
# 0  0.02280     1.642065  down
# 1  0.01390     1.856985  down
# 2  0.00726     2.139063  down

# %%
x10 = np.arange(len(df10['Panther Pathway'] ))
plt.rcParams["figure.figsize"] = [10, 15]
df10["log10pvalue"].plot(kind='barh', legend=False, 
                color=(df10['Fold Enrichment'] > 0).map({True: 'yellowgreen',
                                                    False: 'indianred'}))
plt.title("Differentially regulated Panther Pathways in CM10")
plt.xlabel('-log10(p value)')
plt.ylabel("Panther Pathways")
plt.yticks(x10, df10["Panther Pathway"])
plt.savefig('Differentially regulated Panther Pathways in CM10.png',dpi=300, bbox_inches='tight')

# %% [markdown]
# dfp1 = pd.read_csv('./popdc1null_GO_Biological_Processes_Fold_Enrichment.csv')
# dfp1.head(10)

# %% [markdown]
# xp1 = np.arange(len(dfp1['GO Biological processes'] ))
# plt.rcParams["figure.figsize"] = [10, 15]
# dfp1["log10pvalue"].plot(kind='barh',
#                 color=(dfp1['Fold Enrichment'] > 0).map({True: 'yellowgreen',
#                                                     False: 'indianred'}))
# plt.title("Differentially regulated GO biological processes in popdc1 null")
# plt.xlabel('-log10(p value)')
# plt.ylabel("GO Biological Process")
# plt.yticks(xp1, dfp1["GO Biological processes"])
# plt.savefig('Differentially regulated GO biological processes in popdc1 null.png',dpi=300, bbox_inches='tight')
