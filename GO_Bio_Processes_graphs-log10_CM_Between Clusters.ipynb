# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df3 = pd.read_csv('./CM3_GO_Biological_Process.csv')
df3.head(10)
#this is between clusters as there were so few wt in this population
# Out:
#                            GO Biological processes  Fold Enrichment   p-value  \
# 0                  biological_process (GO:0008150)            -1.16  0.003090
# 1                    cellular process (GO:0009987)            -1.28  0.000518
# 2  anatomical structure morphogenesis (GO:0009653)            -2.32  0.000166
# 3              epithelium development (GO:0060429)            -2.82  0.019400
# 4          animal organ morphogenesis (GO:0009887)            -3.09  0.002490
# 5         embryonic organ development (GO:0048568)            -3.58  0.001880
# 6                tissue morphogenesis (GO:0048729)            -3.90  0.000448
# 7       embryonic organ morphogenesis (GO:0048562)            -4.18  0.002640
# 8      morphogenesis of an epithelium (GO:0002009)            -4.41  0.000125
# 9       epithelial tube morphogenesis (GO:0060562)            -5.45  0.002510
#
#    log10pvalue   Reg
# 0         1.16  down
# 1         1.28  down
# 2         2.32  down
# 3         2.82  down
# ...

# %%
x3 = np.arange(len(df3['GO Biological processes'] ))
plt.rcParams["figure.figsize"] = [10, 15]
df3["log10pvalue"].plot(kind='barh', legend=False, 
                color=(df3['Fold Enrichment'] > 0).map({True: 'yellowgreen',
                                                    False: 'indianred'}))
plt.title("Differentially regulated GO biological processes in CM3")
plt.xlabel('-log10(p value)')
plt.ylabel("GO Biological Process")
plt.yticks(x3, df3["GO Biological processes"])
plt.savefig('Differentially regulated GO biological processes in CM3.png',dpi=300, bbox_inches='tight')

# %%
df1 = pd.read_csv('./CM1_GO_Biological_Process.csv')
df1.head(3)
# Out:
#                        GO Biological processes  Fold Enrichment  p-value  \
# 0  morphogenesis of an epithelium (GO:0002009)            -4.20   0.0389
# 1        animal organ development (GO:0048513)            -2.14   0.0231
# 2            tissue morphogenesis (GO:0048729)            -4.06   0.0134
#
#    log10pvalue   Reg
# 0     1.410050  down
# 1     1.636388  down
# 2     1.872895  down

# %%
x1 = np.arange(len(df1['GO Biological processes'] ))
plt.rcParams["figure.figsize"] = [10, 15]
df1["log10pvalue"].plot(kind='barh', legend=False, 
                color=(df1['Fold Enrichment'] > 0).map({True: 'yellowgreen',
                                                    False: 'indianred'}))
plt.title("Differentially regulated GO biological processes in CM1")
plt.xlabel('-log10(p value)')
plt.ylabel("GO Biological Process")
plt.yticks(x1, df1["GO Biological processes"])
plt.savefig('Differentially regulated GO biological processes in CM1.png',dpi=300, bbox_inches='tight')

# %%
df2 = pd.read_csv('./CM2_GO_Biological_Process.csv')
df2.head(10)
# Out:
#                            GO Biological processes  Fold Enrichment  \
# 0       cellular response to stimulus (GO:0051716)            -1.76
# 1                 signal transduction (GO:0007165)            -1.91
# 2      regulation of cellular process (GO:0050794)            -1.47
# 3               biological regulation (GO:0065007)            -1.44
# 4  anatomical structure morphogenesis (GO:0009653)            -2.46
# 5                           signaling (GO:0023052)            -1.99
# 6      circulatory system development (GO:0072359)            -3.60
# 7                  cell communication (GO:0007154)            -2.00
# 8          nervous system development (GO:0007399)            -2.84
# 9                  system development (GO:0048731)            -2.38
#
#         p-value  log10pvalue   Reg
# 0  4.890000e-02     1.310691  down
# 1  2.390000e-02     1.621602  down
# 2  1.730000e-02     1.761954  down
# 3  5.920000e-03     2.227678  down
# 4  4.020000e-03     2.395774  down
# ...

# %%
x2 = np.arange(len(df2['GO Biological processes'] ))
plt.rcParams["figure.figsize"] = [10, 15]
df2["log10pvalue"].plot(kind='barh', legend=False, 
                color=(df2['Fold Enrichment'] > 0).map({True: 'yellowgreen',
                                                    False: 'indianred'}))
plt.title("Differentially regulated GO biological processes in CM2")
plt.xlabel('-log10(p value)')
plt.ylabel("GO Biological Process")
plt.yticks(x2, df2["GO Biological processes"])
plt.savefig('Differentially regulated GO biological processes in CM2.png',dpi=300, bbox_inches='tight')

# %%
df4 = pd.read_csv('./CM4_GO_Biological_Process.csv')
df4.head(10)
# Out:
#                              GO Biological processes  Fold Enrichment  \
# 0  purine ribonucleotide biosynthetic process (GO...        -0.700704
# 1  ribose phosphate biosynthetic process (GO:0046...        -0.671173
# 2   ribonucleotide biosynthetic process (GO:0009260)        -0.684845
# 3  organophosphate biosynthetic process (GO:0090407)        -0.523746
# 4            acyl-CoA metabolic process (GO:0006637)        -0.899821
# 5           thioester metabolic process (GO:0035383)        -0.899821
# 6  purine nucleoside bisphosphate metabolic proce...        -0.860937
# 7  ribonucleoside bisphosphate metabolic process ...        -0.860937
# 8  nucleoside bisphosphate metabolic process (GO:...        -0.860937
# 9  energy derivation by oxidation of organic comp...        -0.738781
#
#    p-value  log10pvalue   Reg
# 0  0.04400     1.356547  down
# 1  0.03790     1.421361  down
# 2  0.02750     1.560667  down
# 3  0.02260     1.645892  down
# 4  0.02020     1.694649  down
# ...

# %%
x4 = np.arange(len(df4['GO Biological processes'] ))
plt.rcParams["figure.figsize"] = [10, 15]
df4["log10pvalue"].plot(kind='barh', legend=False, 
                color=(df4['Fold Enrichment'] > 0).map({True: 'yellowgreen',
                                                    False: 'indianred'}))
plt.title("Differentially regulated GO biological processes in CM4")
plt.xlabel('-log10(p value)')
plt.ylabel("GO Biological Process")
plt.yticks(x4, df4["GO Biological processes"])
plt.savefig('Differentially regulated GO biological processes in CM4.png',dpi=300, bbox_inches='tight')

# %%
df5 = pd.read_csv('./CM5_GO_Biological_Process.csv')
df5.head(10)
# Out:
#                              GO Biological processes  Fold Enrichment  \
# 0   regulation of vascular permeability (GO:0043114)          -100.00
# 1                   homeostatic process (GO:0042592)             5.04
# 2             immune system development (GO:0002520)             7.38
# 3  hematopoietic or lymphoid organ development (G...             7.52
# 4                           hemopoiesis (GO:0030097)             7.79
# 5                         gas transport (GO:0015669)            64.89
# 6          myeloid cell differentiation (GO:0030099)            14.42
# 7           erythrocyte differentiation (GO:0030218)            25.01
# 8                 embryonic hemopoiesis (GO:0035162)            30.28
# 9        homeostasis of number of cells (GO:0048872)            22.41
#
#     p-value  log10pvalue   Reg
# 0  0.022600     1.645892  down
# 1  0.044900     1.347754    up
# 2  0.016100     1.793174    up
# 3  0.013800     1.860121    up
# 4  0.010500     1.978811    up
# ...

# %%
x5 = np.arange(len(df5['GO Biological processes'] ))
plt.rcParams["figure.figsize"] = [10, 15]
df5["log10pvalue"].plot(kind='barh', legend=False, 
                color=(df5['Fold Enrichment'] > 0).map({True: 'yellowgreen',
                                                    False: 'indianred'}))
plt.title("Differentially regulated GO biological processes in CM5")
plt.xlabel('-log10(p value)')
plt.ylabel("GO Biological Process")
plt.yticks(x5, df5["GO Biological processes"])
plt.savefig('Differentially regulated GO biological processes in CM5.png',dpi=300, bbox_inches='tight')

# %%
df6 = pd.read_csv('./CM6_GO_Biological_Process.csv')
df6.head(10)
# Out:
#                   GO Biological processes  Fold Enrichment  p-value  \
# 0  stem cell differentiation (GO:0048863)            16.91  0.00653
#
#    log10pvalue Reg
# 0     2.185087  up

# %%
x6 = np.arange(len(df6['GO Biological processes'] ))
plt.rcParams["figure.figsize"] = [10, 15]
df6["log10pvalue"].plot(kind='barh', legend=False, 
                color=(df6['Fold Enrichment'] > 0).map({True: 'yellowgreen',
                                                    False: 'indianred'}))
plt.title("Differentially regulated GO biological processes in CM6")
plt.xlabel('-log10(p value)')
plt.ylabel("GO Biological Process")
plt.yticks(x6, df6["GO Biological processes"])
plt.savefig('Differentially regulated GO biological processes in CM6.png',dpi=300, bbox_inches='tight')

# %% [markdown]
# df7 = pd.read_csv('./Geno_CM7_GO_Biological_Processes_Fold_Enrichment.csv')
# df7.head(10)

# %% [markdown]
# x7 = np.arange(len(df7['GO Biological processes'] ))
# plt.rcParams["figure.figsize"] = [10, 15]
# df7["log10pvalue"].plot(kind='barh', legend=False,
#                 color=(df7['Fold Enrichment'] > 0).map({True: 'yellowgreen',
#                                                     False: 'indianred'}))
# plt.title("Differentially regulated GO biological processes in CM7")
# plt.xlabel('-log10(p value)')
# plt.ylabel("GO Biological Process")
# plt.yticks(x7, df7["GO Biological processes"])
# plt.savefig('Differentially regulated GO biological processes in CM7.png',dpi=300, bbox_inches='tight')

# %%
df8 = pd.read_csv('./CM8_GO_Biological_Process.csv')
df8.head(10)
# Out:
#                              GO Biological processes  Fold Enrichment  \
# 0  purine ribonucleotide metabolic process (GO:00...            12.00
# 1  nucleoside triphosphate biosynthetic process (...            33.40
# 2   protein-containing complex assembly (GO:0065003)             6.70
# 3                    organelle assembly (GO:0070925)             7.28
# 4  mitochondrial ATP synthesis coupled electron t...            43.26
# 5                rRNA metabolic process (GO:0016072)            17.00
# 6  embryo development ending in birth or egg hatc...             8.30
# 7                       rRNA processing (GO:0006364)            17.85
# 8        chordate embryonic development (GO:0043009)             8.33
# 9  cellular protein-containing complex assembly (...             8.55
#
#    p-value  log10pvalue Reg
# 0  0.04990     1.301899  up
# 1  0.03430     1.464706  up
# 2  0.03080     1.511449  up
# 3  0.01590     1.798603  up
# 4  0.01300     1.886057  up
# ...

# %%
x8 = np.arange(len(df8['GO Biological processes'] ))
plt.rcParams["figure.figsize"] = [10, 15]
df8["log10pvalue"].plot(kind='barh', legend=False, 
                color=(df8['Fold Enrichment'] > 0).map({True: 'yellowgreen',
                                                    False: 'indianred'}))
plt.title("Differentially regulated GO biological processes in CM8")
plt.xlabel('-log10(p value)')
plt.ylabel("GO Biological Process")
plt.yticks(x8, df8["GO Biological processes"])
plt.savefig('Differentially regulated GO biological processes in CM8.png',dpi=300, bbox_inches='tight')

# %%
df10 = pd.read_csv('./CM10_GO_Biological_Process.csv')
df10.head(10)
# Out:
#                              GO Biological processes  Fold Enrichment  \
# 0                     blood circulation (GO:0008015)            -9.48
# 1                epithelium development (GO:0060429)            -4.39
# 2              animal organ development (GO:0048513)            -2.75
# 3                    tissue development (GO:0009888)            -3.58
# 4                 muscle system process (GO:0003012)           -16.72
# 5  regulation of multicellular organismal process...            -5.13
# 6     supramolecular fiber organization (GO:0097435)            -6.60
# 7  striated muscle cell differentiation (GO:0051146)           -11.36
# 8           muscle cell differentiation (GO:0042692)           -11.17
# 9      striated muscle cell development (GO:0055002)           -14.32
#
#     p-value  log10pvalue   Reg
# 0  0.047200     1.326058  down
# 1  0.035400     1.450997  down
# 2  0.014500     1.838632  down
# 3  0.009380     2.027797  down
# 4  0.009260     2.033389  down
# ...

# %%
x10 = np.arange(len(df10['GO Biological processes'] ))
plt.rcParams["figure.figsize"] = [10, 15]
df10["log10pvalue"].plot(kind='barh', legend=False, 
                color=(df10['Fold Enrichment'] > 0).map({True: 'yellowgreen',
                                                    False: 'indianred'}))
plt.title("Differentially regulated GO biological processes in CM10")
plt.xlabel('-log10(p value)')
plt.ylabel("GO Biological Process")
plt.yticks(x10, df10["GO Biological processes"])
plt.savefig('Differentially regulated GO biological processes in CM10.png',dpi=300, bbox_inches='tight')

# %% [markdown]
# dfp1 = pd.read_csv('./popdc1null_GO_Biological_Processes_Fold_Enrichment.csv')
# dfp1.head(10)

# %% [markdown]
# xp1 = np.arange(len(dfp1['GO Biological processes'] ))
# plt.rcParams["figure.figsize"] = [10, 15]
# dfp1["log10pvalue"].plot(kind='barh',
#                 color=(dfp1['Fold Enrichment'] > 0).map({True: 'yellowgreen',
#                                                     False: 'indianred'}))
# plt.title("Differentially regulated GO biological processes in popdc1 null")
# plt.xlabel('-log10(p value)')
# plt.ylabel("GO Biological Process")
# plt.yticks(xp1, dfp1["GO Biological processes"])
# plt.savefig('Differentially regulated GO biological processes in popdc1 null.png',dpi=300, bbox_inches='tight')

# %%
df3p = pd.read_csv('./CM3_P1_GO_Biological_Process.csv')
df3p.head(10)
#this is between clusters as there were so few wt in this population
# Out:
#                              GO Biological processes  Fold Enrichment  \
# 0                    synaptic signaling (GO:0099536)           -15.56
# 1     supramolecular fiber organization (GO:0097435)             5.80
# 2     skeletal muscle organ development (GO:0060538)            13.60
# 3       regulation of heart contraction (GO:0008016)            20.40
# 4             cytoskeleton organization (GO:0007010)             4.24
# 5    skeletal muscle tissue development (GO:0007519)            15.03
# 6                              behavior (GO:0007610)            11.29
# 7           muscle cell differentiation (GO:0042692)             9.60
# 8  cellular component assembly involved in morpho...            16.96
# 9                    myofibril assembly (GO:0030239)            18.03
#
#    p-value  log10pvalue   Reg
# 0  0.00849     2.071092  down
# 1  0.04220     1.374688    up
# 2  0.02920     1.534617    up
# 3  0.02740     1.562249    up
# 4  0.02330     1.632644    up
# ...

# %%
x3p = np.arange(len(df3p['GO Biological processes'] ))
plt.rcParams["figure.figsize"] = [10, 15]
df3p["log10pvalue"].plot(kind='barh', legend=False, 
                color=(df3p['Fold Enrichment'] > 0).map({True: 'yellowgreen',
                                                    False: 'indianred'}))
plt.title("Differentially regulated GO biological processes in CM3")
plt.xlabel('-log10(p value)')
plt.ylabel("GO Biological Process")
plt.yticks(x3p, df3p["GO Biological processes"])
plt.savefig('Differentially regulated GO biological processes in CM3 p1.png',dpi=300, bbox_inches='tight')
