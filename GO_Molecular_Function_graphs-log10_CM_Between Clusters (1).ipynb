# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df3 = pd.read_csv('./CM3_GO_Molecular_Function.csv')
df3.head(10)
#this is between clusters as there were so few wt in this population
# Out:
#                                GO Molecular Function  Fold Enrichment  \
# 0  amylo-alpha-1,6-glucosidase activity (GO:0004135)           -98.84
# 1   4-alpha-glucanotransferase activity (GO:0004134)           -98.84
# 2  glycogen debranching enzyme activity (GO:0004133)           -98.84
# 3                         actin binding (GO:0003779)             3.94
#
#    p-value  log10pvalue   Reg
# 0   0.0400     1.397940  down
# 1   0.0400     1.397940  down
# 2   0.0400     1.397940  down
# 3   0.0209     1.679854    up

# %%
x3 = np.arange(len(df3['GO Molecular Function'] ))
plt.rcParams["figure.figsize"] = [10, 8]
df3["log10pvalue"].plot(kind='barh', legend=False, 
                color=(df3['Fold Enrichment'] > 0).map({True: 'yellowgreen',
                                                    False: 'indianred'}))
plt.title("Differentially regulated GO Molecular Function in CM3")
plt.xlabel('-log10(p value)')
plt.ylabel("GO Molecular Function")
plt.yticks(x3, df3["GO Molecular Function"])
plt.savefig('Differentially regulated GO Molecular Function in CM3.png',dpi=300, bbox_inches='tight')

# %%
df1 = pd.read_csv('./CM1_GO_Molecular_Function.csv')
df1.head(3)
# Out:
#                             GO Molecular Functions  Fold Enrichment  \
# 0  protein-containing complex binding (GO:0044877)            -4.25
# 1              actin filament binding (GO:0051015)            -8.17
# 2        cytoskeletal protein binding (GO:0008092)            -4.59
#
#         p-value  log10pvalue   Reg
# 0  1.750000e-03     2.756962  down
# 1  8.510000e-06     5.070070  down
# 2  3.410000e-07     6.467246  down

# %%
x1 = np.arange(len(df1['GO Molecular Functions'] ))
plt.rcParams["figure.figsize"] = [10, 15]
df1["log10pvalue"].plot(kind='barh', legend=False, 
                color=(df1['Fold Enrichment'] > 0).map({True: 'yellowgreen',
                                                    False: 'indianred'}))
plt.title("Differentially regulated GO Molecular Functions in CM1")
plt.xlabel('-log10(p value)')
plt.ylabel("GO Molecular Function")
plt.yticks(x1, df1["GO Molecular Functions"])
plt.savefig('Differentially regulated GO Molecular Function in CM1.png',dpi=300, bbox_inches='tight')

# %%
df2 = pd.read_csv('./CM2_GO_Molecular_Function.csv')
df2.head(10)
# Out:
#          GO Molecular Functions  Fold Enrichment   p-value  log10pvalue Reg
# 0  protein binding (GO:0005515)             2.03  0.000619     3.208309  up

# %%
x2 = np.arange(len(df2['GO Molecular Functions'] ))
plt.rcParams["figure.figsize"] = [10, 15]
df2["log10pvalue"].plot(kind='barh', legend=False, 
                color=(df2['Fold Enrichment'] > 0).map({True: 'yellowgreen',
                                                    False: 'indianred'}))
plt.title("Differentially regulated GO Molecular Function in CM2")
plt.xlabel('-log10(p value)')
plt.ylabel("GO Molecular Function")
plt.yticks(x2, df2["GO Molecular Functions"])
plt.savefig('Differentially regulated GO Molecular Function in CM2.png',dpi=300, bbox_inches='tight')

# %%
df4 = pd.read_csv('./CM4_GO_Molecular_Function.csv')
df4.head(10)
# Out:
#                                GO Molecular Function  Fold Enrichment  \
# 0    transmembrane transporter activity (GO:0022857)            -1.98
# 1  phosphatidylinositol 3-kinase binding (GO:0043...           -20.49
# 2       carbohydrate derivative binding (GO:0097367)            -1.71
# 3  purine ribonucleoside triphosphate binding (GO...            -1.77
# 4                    catalytic activity (GO:0003824)            -1.38
# 5                           ATP binding (GO:0005524)            -1.91
# 6                  transporter activity (GO:0005215)            -2.02
# 7             purine nucleotide binding (GO:0017076)            -1.79
# 8                ribonucleotide binding (GO:0032553)            -1.79
# 9         purine ribonucleotide binding (GO:0032555)            -1.80
#
#    p-value  log10pvalue   Reg
# 0  0.04170     1.379864  down
# 1  0.02830     1.548214  down
# 2  0.01610     1.793174  down
# 3  0.01210     1.917215  down
# 4  0.01040     1.982967  down
# 5  0.00858     2.066513  down
# 6  0.00783     2.106238  down
# 7  0.00503     2.298432  down
# 8  0.00470     2.327902  down
# 9  0.00435     2.361511  down

# %%
x4 = np.arange(len(df4['GO Molecular Function'] ))
plt.rcParams["figure.figsize"] = [10, 15]
df4["log10pvalue"].plot(kind='barh', legend=False, 
                color=(df4['Fold Enrichment'] > 0).map({True: 'yellowgreen',
                                                    False: 'indianred'}))
plt.title("Differentially regulated GO Molecular Function in CM4")
plt.xlabel('-log10(p value)')
plt.ylabel("GO Molecular Function")
plt.yticks(x4, df4["GO Molecular Function"])
plt.savefig('Differentially regulated GO Molecular Function in CM4.png',dpi=300, bbox_inches='tight')

# %%
df5 = pd.read_csv('./CM5_GO_Molecular_Function.csv')
df5.head(10)
# Out:
#             GO Biological processes  Fold Enrichment  p-value  log10pvalue Reg
# 0  haptoglobin binding (GO:0031720)            77.87   0.0262     1.581699  up

# %%
x5 = np.arange(len(df5['GO Biological processes'] ))
plt.rcParams["figure.figsize"] = [10, 15]
df5["log10pvalue"].plot(kind='barh', legend=False, 
                color=(df5['Fold Enrichment'] > 0).map({True: 'yellowgreen',
                                                    False: 'indianred'}))
plt.title("Differentially regulated GO Molecular Function in CM5")
plt.xlabel('-log10(p value)')
plt.ylabel("GO Molecular Function")
plt.yticks(x5, df5["GO Biological processes"])
plt.savefig('Differentially regulated GO Molecular Function in CM5.png',dpi=300, bbox_inches='tight')

# %%
df6 = pd.read_csv('./CM6_GO_Molecular_Function.csv')
df6.head(10)
# Out:
#                     GO Molecular Function  Fold Enrichment  p-value  \
# 0  GTPase activator activity (GO:0005096)            15.86  0.00463
# 1  enzyme activator activity (GO:0008047)            12.70  0.00259
#
#    log10pvalue Reg
# 0     2.334419  up
# 1     2.586700  up

# %%
x6 = np.arange(len(df6['GO Molecular Function'] ))
plt.rcParams["figure.figsize"] = [10, 15]
df6["log10pvalue"].plot(kind='barh', legend=False, 
                color=(df6['Fold Enrichment'] > 0).map({True: 'yellowgreen',
                                                    False: 'indianred'}))
plt.title("Differentially regulated GO Molecular Function in CM6")
plt.xlabel('-log10(p value)')
plt.ylabel("GO Molecular Function")
plt.yticks(x6, df6["GO Molecular Function"])
plt.savefig('Differentially regulated GO Molecular Function in CM6.png',dpi=300, bbox_inches='tight')

# %% [markdown]
# df7 = pd.read_csv('./Geno_CM7_GO_Biological_Processes_Fold_Enrichment.csv')
# df7.head(10)

# %% [markdown]
# x7 = np.arange(len(df7['GO Biological processes'] ))
# plt.rcParams["figure.figsize"] = [10, 15]
# df7["log10pvalue"].plot(kind='barh', legend=False,
#                 color=(df7['Fold Enrichment'] > 0).map({True: 'yellowgreen',
#                                                     False: 'indianred'}))
# plt.title("Differentially regulated GO biological processes in CM7")
# plt.xlabel('-log10(p value)')
# plt.ylabel("GO Biological Process")
# plt.yticks(x7, df7["GO Biological processes"])
# plt.savefig('Differentially regulated GO biological processes in CM7.png',dpi=300, bbox_inches='tight')

# %%
df8 = pd.read_csv('./CM8_GO_Molecular_Function.csv')
df8.head(10)
# Out:
#                              GO Biological processes  Fold Enrichment  \
# 0  oxidoreductase activity, acting on NAD(P)H (GO...            29.29
# 1                  nucleic acid binding (GO:0003676)             2.73
# 2  heme-copper terminal oxidase activity (GO:0015...            67.98
# 3         cytochrome-c oxidase activity (GO:0004129)            67.98
# 4  oxidoreductase activity, acting on a heme grou...            67.98
# 5  oxidoreductase activity, acting on a heme grou...            67.98
# 6  oxidoreductase activity, acting on NAD(P)H, qu...            76.14
# 7           NADH dehydrogenase activity (GO:0003954)            79.31
# 8  large ribosomal subunit rRNA binding (GO:0070180)           100.00
# 9  NAD(P)H dehydrogenase (quinone) activity (GO:0...            86.53
#
#     p-value  log10pvalue Reg
# 0  0.027700     1.557520  up
# 1  0.015700     1.804100  up
# 2  0.001220     2.913640  up
# 3  0.001220     2.913640  up
# 4  0.001220     2.913640  up
# 5  0.001220     2.913640  up
# 6  0.000811     3.090979  up
# 7  0.000700     3.154902  up
# 8  0.000624     3.204815  up
# 9  0.000513     3.289883  up

# %%
x8 = np.arange(len(df8['GO Biological processes'] ))
plt.rcParams["figure.figsize"] = [10, 15]
df8["log10pvalue"].plot(kind='barh', legend=False, 
                color=(df8['Fold Enrichment'] > 0).map({True: 'yellowgreen',
                                                    False: 'indianred'}))
plt.title("Differentially regulated GO Molecular Function in CM8")
plt.xlabel('-log10(p value)')
plt.ylabel("GO Molecular Function")
plt.yticks(x8, df8["GO Biological processes"])
plt.savefig('Differentially regulated GO Molecular Function in CM8.png',dpi=300, bbox_inches='tight')

# %%
df10 = pd.read_csv('./CM10_GO_Molecular_Function.csv')
df10.head(10)
# Out:
#                        GO Molecular Function  Fold Enrichment       p-value  \
# 0        actin filament binding (GO:0051015)            -9.76  4.340000e-03
# 1  cytoskeletal protein binding (GO:0008092)            -6.28  3.470000e-06
# 2               protein binding (GO:0005515)            -2.79  5.840000e-07
# 3                 actin binding (GO:0003779)           -11.28  4.860000e-10
#
#    log10pvalue   Reg
# 0     2.362510  down
# 1     5.459671  down
# 2     6.233587  down
# 3     9.313364  down

# %%
x10 = np.arange(len(df10['GO Molecular Function'] ))
plt.rcParams["figure.figsize"] = [10, 15]
df10["log10pvalue"].plot(kind='barh', legend=False, 
                color=(df10['Fold Enrichment'] > 0).map({True: 'yellowgreen',
                                                    False: 'indianred'}))
plt.title("Differentially regulated GO Molecular Functions in CM10")
plt.xlabel('-log10(p value)')
plt.ylabel("GO Molecular Function")
plt.yticks(x10, df10["GO Molecular Function"])
plt.savefig('Differentially regulated GO Molecular Function in CM10.png',dpi=300, bbox_inches='tight')

# %% [markdown]
# dfp1 = pd.read_csv('./popdc1null_GO_Biological_Processes_Fold_Enrichment.csv')
# dfp1.head(10)

# %% [markdown]
# xp1 = np.arange(len(dfp1['GO Biological processes'] ))
# plt.rcParams["figure.figsize"] = [10, 15]
# dfp1["log10pvalue"].plot(kind='barh',
#                 color=(dfp1['Fold Enrichment'] > 0).map({True: 'yellowgreen',
#                                                     False: 'indianred'}))
# plt.title("Differentially regulated GO biological processes in popdc1 null")
# plt.xlabel('-log10(p value)')
# plt.ylabel("GO Biological Process")
# plt.yticks(xp1, dfp1["GO Biological processes"])
# plt.savefig('Differentially regulated GO biological processes in popdc1 null.png',dpi=300, bbox_inches='tight')

# %%
df3p = pd.read_csv('./CM3_P1_GO_Molecular_Function.csv')
df3p.head(10)
#this is between clusters as there were so few wt in this population
# Out:
#           GO Molecular Function  Fold Enrichment  p-value  log10pvalue Reg
# 0  protein binding (GO:0005515)             2.28  0.00412     2.385103  up

# %%
x3p = np.arange(len(df3p['GO Molecular Function'] ))
plt.rcParams["figure.figsize"] = [10, 15]
df3p["log10pvalue"].plot(kind='barh', legend=False, 
                color=(df3p['Fold Enrichment'] > 0).map({True: 'yellowgreen',
                                                    False: 'indianred'}))
plt.title("Differentially regulated GO Molecular Function in CM3")
plt.xlabel('-log10(p value)')
plt.ylabel("GO Molecular Function")
plt.yticks(x3p, df3p["GO Molecular Function"])
plt.savefig('Differentially regulated GO Molecular Function in CM3 p1.png',dpi=300, bbox_inches='tight')
